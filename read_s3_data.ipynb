# %%
# import boto3
import sys
import pandas as pd

# %%
sys.path.insert(0, "/Users/lucas/.pyenv/versions/3.8.5/lib/python3.8/site-packages")
print(sys.path)
# Out:
# ['/Users/lucas/.pyenv/versions/3.8.5/lib/python3.8/site-packages', '/Users/lucas/Documents/GitHub/cross_sell_viewthru', '/usr/local/Cellar/python@3.8/3.8.10/Frameworks/Python.framework/Versions/3.8/lib/python38.zip', '/usr/local/Cellar/python@3.8/3.8.10/Frameworks/Python.framework/Versions/3.8/lib/python3.8', '/usr/local/Cellar/python@3.8/3.8.10/Frameworks/Python.framework/Versions/3.8/lib/python3.8/lib-dynload', '', '/Users/lucas/Library/Python/3.8/lib/python/site-packages', '/usr/local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/site-packages/IPython/extensions', '/Users/lucas/.ipython']

# %%
import boto3

# %%
# Creating the low level functional client
client = boto3.client(
    's3',
    aws_access_key_id = 'AKIATOEFUXJPBKQLQJ63',
    aws_secret_access_key = '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',
    region_name = 'eu-west-1'
)

# %%
# # Fetch the list of existing buckets
# clientResponse = client.list_buckets()
    
# # Print the bucket names one by one
# print('Printing bucket names...')
# for bucket in clientResponse['Buckets']:
#     print(f'Bucket Name: {bucket["Name"]}')

# %%
# Create the S3 object
obj = client.get_object(
    Bucket = 'twigeo-nyt-data-report',
    Key = 'nyt_crosswords_weeklyreport_from_2021-03-21to2021-07-19.csv'
)
    
# Read data from the S3 object
data = pd.read_csv(obj['Body'])
    
# Print the data frame
# print('Printing the data frame...')
# print(data)

# %%
data.head()
# Out:
#    Unnamed: 0        date                                      campaign_name  \
# 0           0  2021-03-21      2020_tg_game_app_asm_ios_us_apl_pros_20200304
# 1           1  2021-03-21  2020_tg_game_app_brand-broad_ios_us_apl_pros_2...
# 2           2  2021-03-21  2020_tg_game_app_brand-broad_ios_us_apl_rmkt_2...
# 3           3  2021-03-21  2020_tg_game_app_brand-exact_ios_us_apl_pros_2...
# 4           4  2021-03-21  2020_tg_game_app_brand-exact_ios_us_apl_rmkt_2...
#
#   Publisher  Investment    Installs  Free Pack  Paid Pack  Pack Purchases  \
# 0     Apple      972.31   95.762712   6.178239   5.148533       11.326772
# 1     Apple        0.87    0.847458   0.000000   0.000000        0.000000
# 2     Apple       15.56    6.779661   3.389831   0.000000        3.389831
# 3     Apple      528.39  155.084746  32.050847   8.271186       40.322034
# 4     Apple      190.48   51.694915   1.813857   0.906928        2.720785
#
# ...

# %%
# df = pd.read_csv('gs://twigeo/nyt_crosswords_weeklyreport_from_2021-03-20to2021-07-18.csv')

# %%
# import logging
# import os
# import cloudstorage as gcs
# # import webapp2

# # from google.appengine.api import app_identity

# %%
# def list_bucket(self, bucket):
#     """Create several files and paginate through them.

#     Production apps should set page_size to a practical value.

#     Args:
#     bucket: bucket.
#     """
#     self.response.write('Listbucket result:\n')

#     page_size = 1
#     stats = gcs.listbucket(bucket + '/foo', max_keys=page_size)
#     while True:
#         count = 0
#         for stat in stats:
#             count += 1
#             self.response.write(repr(stat))
#             self.response.write('\n')

#         if count != page_size or count == 0:
#             break
#         stats = gcs.listbucket(bucket + '/foo', max_keys=page_size,
#                    marker=stat.filename)

# %%
# list_bucket(self, bucket='twigeo')

# %%
# from google.cloud import storage
# client = storage.Client()
# BUCKET_NAME = 'twigeo'
# bucket = client.get_bucket(BUCKET_NAME)
# elements = bucket.list_blobs()
# files=[a.name for a in elements]
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-5-1fa3bdc05b44> in <module>
#       2 client = storage.Client()
#       3 BUCKET_NAME = 'twigeo'
# ----> 4 bucket = client.get_bucket(BUCKET_NAME)
#       5 elements = bucket.list_blobs()
#       6 files=[a.name for a in elements]
#
# /usr/local/lib/python3.8/site-packages/google/cloud/storage/client.py in get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match, retry)
#     400         """
#     401         bucket = self._bucket_arg_to_bucket(bucket_or_name)
# --> 402         bucket.reload(
#     403             client=self,
#     404             timeout=timeout,
#
# /usr/local/lib/python3.8/site-packages/google/cloud/storage/bucket.py in reload(self, client, projection, timeout, if_metageneration_match, if_metageneration_not_match, retry)
# ...
